# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing IMDb Data
#
# _Author: Kevin Markham (DC)_
#
# ---

# %% [markdown]
# For project two, you will complete a serious of exercises exploring movie rating data from IMDb.
#
# For these exercises, you will be conducting basic exploratory data analysis on IMDB's movie data, looking to answer such questions as:
#
# What is the average rating per genre?
# How many different actors are in a movie?
#
# This process will help you practice your data analysis skills while becoming comfortable with Pandas.

# %% [markdown]
# ## Basic level

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read in 'imdb_1000.csv' and store it in a DataFrame named movies.

# %%
movies = pd.read_csv('./data/imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# #### Check the number of rows and columns.

# %%
# Answer:
movies.shape
# Out:
# (979, 6)

# %% [markdown]
# #### Check the data type of each column.

# %%
# Answer:
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# #### Calculate the average movie duration.

# %%
# Answer:
sum(movies['duration'])/len(movies['duration'])
# Out:
# 120.97957099080695

# %% [markdown]
# #### Sort the DataFrame by duration to find the shortest and longest movies.

# %%
# Answer:
movies.duration.sort_values(ascending = True)
# Out:
# 389     64
# 338     66
# 258     67
# 293     68
# 88      68
# 742     69
# 351     70
# 938     75
# 405     75
# 303     76
# 713     78
# 864     78
# 489     78
# 535     79
# 513     80
# 853     80
# 533     80
# 283     80
# 297     80
# 622     80
# 117     81
# 541     81
# 738     81
# 789     81
# 330     81
# 595     82
# 306     82
# 174     83
# 759     83
# 766     83
#       ...
# 361    181
# 166    182
# 109    183
# 245    184
# 132    186
# 611    187
# 318    188
# 184    188
# 89     189
# 316    189
# 40     189
# 671    191
# 220    191
# 424    193
# 620    194
# 8      195
# 385    197
# 335    197
# 2      200
# 7      201
# 630    202
# 767    205
# 17     207
# 204    212
# 85     216
# 445    220
# 142    224
# 78     229
# 157    238
# 476    242
# Name: duration, Length: 979, dtype: int64

# %% [markdown]
# #### Create a histogram of duration, choosing an "appropriate" number of bins.

# %%
# Answer:
movies.hist('duration',bins = 10);

# %% [markdown]
# #### Use a box plot to display that same data.

# %%
# Answer:
movies.boxplot('duration',fontsize = 15,figsize=(10,10));

# %% [markdown]
# ## Intermediate level

# %% [markdown]
# #### Count how many movies have each of the content ratings.

# %%
# Answer:
new_list = movies.content_rating.value_counts()
new_list#new_list.index[:]
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# PASSED         7
# NC-17          7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %% [markdown]
# #### Use a visualization to display that same data, including a title and x and y labels.

# %%
# Answer:
movies.content_rating.value_counts().plot(kind='bar');
plt.title("Total of movies per content rating")
plt.ylabel("Total no. of movies")
# Out:
# Text(0, 0.5, 'Total no. of movies')

# %% [markdown]
# #### Convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP.

# %%
# Answer:
condition = ['NOT RATED','APPROVED','PASSED','GP']
movies.replace(condition,'UNRATED')
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %% [markdown]
# #### Convert the following content ratings to "NC-17": X, TV-MA.

# %%
# Answer:
condition = ['X','TV-MA']
movies.replace(condition,'NC-17')
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %% [markdown]
# #### Count the number of missing values in each column.

# %%
# Answer:
print((movies.isnull().sum()))
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %% [markdown]
# #### If there are missing values: examine them, then fill them in with "reasonable" values.

# %%
# Answer:
movies.content_rating.fillna(value='Not Given')
# Out:
# 0              R
# 1              R
# 2              R
# 3          PG-13
# 4              R
# 5      NOT RATED
# 6      NOT RATED
# 7          PG-13
# 8              R
# 9              R
# 10         PG-13
# 11         PG-13
# 12            PG
# 13         PG-13
# 14         PG-13
# 15         PG-13
# 16             R
# 17       UNRATED
# 18             R
# 19            PG
# 20             R
# 21             R
# 22      APPROVED
# 23             R
# 24             R
# 25         PG-13
# 26         PG-13
# 27             R
# 28             R
# 29        PASSED
#          ...
# 949           PG
# 950            R
# 951            R
# 952            R
# 953           PG
# 954        PG-13
# 955            R
# 956           PG
# 957            R
# 958        PG-13
# 959            R
# 960        PG-13
# 961            R
# 962           PG
# 963            R
# 964        PG-13
# 965        PG-13
# 966        PG-13
# 967            R
# 968            R
# 969            R
# ...

# %% [markdown]
# #### Calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours.

# %%
# Answer:
two_hrs = movies['duration'] >= 120
average_1 = float(movies[two_hrs].star_rating.mean())
less_two = movies['duration'] < 120
average_2 = float(movies[less_two].star_rating.mean())

print("Movies that are two hr(or more) and two hrs(or less) have an average score of %.2f and %.2f respectively"%(average_1, average_2))
# Out:
# Movies that are two hr(or more) and two hrs(or less) have an average score of 7.95 and 7.84 respectively

# %% [markdown]
# #### Use a visualization to detect whether there is a relationship between duration and star rating.

# %%
# Answer:
movies.boxplot(column='duration', by='star_rating');

# %% [markdown]
# #### Calculate the average duration for each genre.

# %%
# Answer:
movies[['duration','genre']].groupby('genre').mean()
# Out:
#              duration
# genre
# Action     126.485294
# Adventure  134.840000
# Animation   96.596774
# Biography  131.844156
# Comedy     107.602564
# Crime      122.298387
# Drama      126.539568
# Family     107.500000
# Fantasy    112.000000
# Film-Noir   97.333333
# History     66.000000
# Horror     102.517241
# Mystery    115.625000
# Sci-Fi     109.000000
# Thriller   114.200000
# Western    136.666667

# %% [markdown]
# ## Advanced level

# %% [markdown]
# #### Visualize the relationship between content rating and duration.

# %%
# Answer:
movies.boxplot(column= 'duration',by= 'content_rating');

# %% [markdown]
# #### Determine the top rated movie (by star rating) for each genre.

# %%
# Answer:
movies.sort_values('star_rating', ascending=False).groupby('genre')['title','star_rating'].first()
# Out:
#                                                    title  star_rating
# genre
# Action                                   The Dark Knight          9.0
# Adventure  The Lord of the Rings: The Return of the King          8.9
# Animation                                  Spirited Away          8.6
# Biography                               Schindler's List          8.9
# Comedy                                      Modern Times          8.6
# Crime                           The Shawshank Redemption          9.3
# Drama                                       12 Angry Men          8.9
# Family                        E.T. the Extra-Terrestrial          7.9
# Fantasy                        The City of Lost Children          7.7
# Film-Noir                                  The Third Man          8.3
# History                              Battleship Potemkin          8.0
# Horror                                            Psycho          8.6
# ...

# %% [markdown]
# #### Check if there are multiple movies with the same title, and if so, determine if they are actually duplicates.

# %%
# Answer:
result = movies[movies['title'].isin(movies[movies.duplicated(['title'])]['title'])]
result.sort_values('title')
# Out:
#      star_rating                            title content_rating      genre  \
# 703          7.6                          Dracula       APPROVED     Horror
# 905          7.5                          Dracula              R     Horror
# 678          7.7                   Les Miserables          PG-13      Drama
# 924          7.5                   Les Miserables          PG-13      Crime
# 466          7.9  The Girl with the Dragon Tattoo              R      Crime
# 482          7.8  The Girl with the Dragon Tattoo              R      Crime
# 662          7.7                        True Grit          PG-13  Adventure
# 936          7.4                        True Grit            NaN  Adventure
#
#      duration                                        actors_list
# 703        85  [u'Bela Lugosi', u'Helen Chandler', u'David Ma...
# 905       128  [u'Gary Oldman', u'Winona Ryder', u'Anthony Ho...
# 678       158  [u'Hugh Jackman', u'Russell Crowe', u'Anne Hat...
# ...

# %% [markdown]
# #### Calculate the average star rating for each genre, but only include genres with at least 10 movies

# %% [markdown]
# #### Option 1: manually create a list of relevant genres, then filter using that list

# %%
# Answer:
genre_list = ['Drama','Comedy', 'Action', 'Crime', 'Biography', 'Adventure', 'Animation', 'Horror'
             , 'Mystery']
movies[movies.genre.isin(genre_list)].groupby('genre').star_rating.mean()
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %%
# Answer:
genre_count = movies.genre.value_counts()
top_movies = genre_count[genre_count >= 10].index
movies[movies.genre.isin(top_movies)].groupby('genre').star_rating.mean()
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 3: calculate the average star rating for all genres, then filter using a boolean Series

# %%
# Answer:
movies.groupby('genre').star_rating.mean()[movies.genre.value_counts() >= 10]
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 4: aggregate by count and mean, then filter using the count

# %%
# Answer:
genre_ratings = movies.groupby('genre').star_rating.agg(['count', 'mean'])
genre_ratings[genre_ratings['count'] >= 10]
# Out:
#            count      mean
# genre
# Action       136  7.884559
# Adventure     75  7.933333
# Animation     62  7.914516
# Biography     77  7.862338
# Comedy       156  7.822436
# Crime        124  7.916935
# Drama        278  7.902518
# Horror        29  7.806897
# Mystery       16  7.975000

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Figure out something "interesting" using the actors data!
